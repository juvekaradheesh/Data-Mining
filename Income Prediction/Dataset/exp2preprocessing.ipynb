# %%
# %matplotlib inline

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Reason for %matplotlib inline to be before importing matplotlib
#I believe its needed because normally matplotlib opens additional windows for graphs using a default toolkit. 
#The %inline lets you load graphs in the IPython notebook, instead of using an external toolkit.

# %%
df = pd.read_csv("adult.csv")
df = df.replace(" ",np.nan)
df.head()
# Out:
#    Age          WorkClass  Final_wt   Education  Edu_num         Marital_stat  \
# 0   39          State-gov     77516   Bachelors       13        Never-married
# 1   50   Self-emp-not-inc     83311   Bachelors       13   Married-civ-spouse
# 2   38            Private    215646     HS-grad        9             Divorced
# 3   53            Private    234721        11th        7   Married-civ-spouse
# 4   28            Private    338409   Bachelors       13   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  cpt_gain  cpt_loss  \
# 0        Adm-clerical   Not-in-family   White     Male      2174         0
# 1     Exec-managerial         Husband   White     Male         0         0
# 2   Handlers-cleaners   Not-in-family   White     Male         0         0
# 3   Handlers-cleaners         Husband   Black     Male         0         0
# 4      Prof-specialty            Wife   Black   Female         0         0
#
#    Hr_per_week  Native_country  Salary
# ...

# %%
##df.fillna?## documentation for handling missing values
##VISUALIZATION###
#sns.boxplot(x="Age",y="Salary",data=df)
#sns.pairplot(df,hue="Salary") #Finding relationships across multiple dimensions
sns.pairplot(df,kind="reg")
#sns.boxplot(data=df)
